# %%
# Print a welcome message

hod = "Hall of Doors"

print(f" Welcome to the {hod}!")
print()
print("In this game, you will choose a one door from a choice of five doors.  Through each door lies options for you to explore different countries with different experiences.  Enjoy the journey!")
print()
print ("Off We Go!")
print()

# Ask User for their name

name = input("What is your name, brave adventurer?")

print()

print(f"Welcome {name} to the {hod}...")

# Choose Your Adventure Introduction

print(("You stand in a vast, circular hall. In front of you are five mysterious, ornate doors, each shimmering with a different color. A soft voice whispers, 'Choose a door, and an adventure will unfold.'"))

print()

# Ask User for input number and door choice

door_choice = input("Choose a number 1, 2, 3, 4, or 5: ")

# Convert door choice into an integer

door_choice = int(door_choice)

# Storing each country in a variable

country_1 = "Greece"
country_2 = "Costa Rica"
country_3 = "Japan"
country_4 = "Egypt"
country_5 = "Iceland"

# if-elif-else chain

# if-elif-elise statement of door choice 1

if door_choice == 1:
    print(f"{name}, you chose the Azure Door and are now are transported to a wondrous adventure in {country_1}")

# Ask User to select A or B for their Greece adventure

    greece_choice = input("Do you A) explore the ancient ruins of the Acropolis? or B) sail the turquoise waters of the Aegean Sea? ")

# If statement of option A

    if greece_choice.upper() == 'A':
        print("You discover a hidden chamber under the Parthenon, filled with ancient scrolls. Your adventure is one of historical discovery!")

# Elif statement of option B

    elif greece_choice.upper() == 'B':
        print("A pod of playful dolphins guides your boat to a secluded island with a pristine beach. Your adventure is one of serene natural beauty!")

# Else statement of invalid choice

    else:
        print("Even the simplest of directions are hard for you to follow...you don't belong to this world...your adventure is over before even starting!")


# if-elif-elise statement of door choice 2

elif door_choice == 2:
    print(f" {name}, you chose the Emerald Door and are now are transported to a wondrous adventure in {country_2}!")

# Ask User to select A or B for their Costa Rica adventure

    costa_rica_choice = input("Do you A) zipline through the misty cloud forest canopy? or B) watch sea turtles nest on a moonlit beach?")

# If statement of option A

    if costa_rica_choice.upper() == 'A':
        print("As you soar through the trees, you spot a rare, vibrant quetzal bird. Your adventure is a thrilling encounter with wildlife!")

# Elif statement of option B

    elif costa_rica_choice.upper() == 'B':
        print("You witness the magical, ancient ritual of baby turtles hatching and making their way to the ocean. Your adventure is a moment of profound connection to nature.")

# Else statement of invalid choice

    else:
        print("Even the simplest of directions are hard for you to follow...you don't belong to this world...your adventure is over before even starting!")

# if-elif-elise statement of door choice 3

elif door_choice == 3:
    print(f" {name}, you chose the Crimson Door and are now are transported to a wondrous adventure in {country_3}!")

# Ask User to select A or B for their Japan adventure

    japan_choice = input ("Do you A) get lost in the neon-lit, bustling streets of Tokyo? or B) find peace in a tranquil Kyoto temple garden?")

# If statement of option A

    if japan_choice.upper() == 'A':
        print("You stumble upon a tiny, hidden ramen shop and eat the most delicious meal of your life. Your adventure is a feast for the senses!")

# Elif statement of option B

    elif japan_choice.upper() == 'B':
        print("While meditating by a koi pond, you achieve a moment of perfect clarity and calm. Your adventure is one of inner peace.")

# Else statement of invalid choice

    else:
        print("Even the simplest of directions are hard for you to follow...you don't belong to this world...your adventure is over before even starting!")

# if-elif-elise statement of door choice 4

elif door_choice == 4:
    print(f" {name}, you chose the Golden Door and are now are transported to a wondrous adventure in {country_4}!")

# Ask User to select A or B for their Eygpt adventure

    egypt_choice = input ("Do you A) explore the dusty interior of the Great Pyramid of Giza? or B) sail down the timeless Nile River on a felucca?")

# If statement of option A

    if egypt_choice.upper() == 'A':
        print("Your torchlight reveals a hieroglyph no one has ever seen before, telling a forgotten queen's story. Your adventure is a legendary discovery!")

# Elif statement of option B

    elif egypt_choice.upper() == 'B':
        print ("You watch a breathtaking sunset paint the desert sky orange and purple as ancient temples drift by. Your adventure is one of majestic beauty.")

# Else statement of invalid choice

    else:
        print("Even the simplest of directions are hard for you to follow...you don't belong to this world...your adventure is over before even starting!")

# if-elif-elise statement of door choice 5

elif door_choice == 5:
    print(f" {name}, you chose the Icy Door and are now are transported to a wondrous adventure in {country_5}!")

# Ask User to select A or B for their Iceland adventure

    iceland_choice = input ("Do you A) trek across a glacier to witness the Northern Lights? or B) bathe in the warm, mineral-rich waters of a geothermal lagoon?")

# If statement of option A

    if iceland_choice.upper() == 'A':
        print("The sky explodes in a curtain of green and pink light, a celestial dance just for you. Your adventure is one of cosmic wonder!")

# Elif statement of option B

    elif iceland_choice.upper() == 'B':
        print("As steam rises around you, the stress of the world melts away, leaving you feeling completely renewed. Your adventure is one of pure rejuvenation.")

# Else statement of invalid choice

    else:
        print("Even the simplest of directions are hard for you to follow...You don't belong to this world...your adventure is over before even starting")

# If statement if door choice is not 1-5

if door_choice not in [1, 2, 3, 4, 5]:
     print("Even the simplest of directions are hard for you to follow...You don't belong to this world...your adventure is over before even starting")

# Print end statement
print()
print(f" Thank you {name} for playing the {hod}!  We hope to see you again!")
# Out:
#  Welcome to the Hall of Doors!
#
# In this game, you will choose a one door from a choice of five doors.  Through each door lies options for you to explore different countries with different experiences.  Enjoy the journey!
#
# Off We Go!
#
# What is your name, brave adventurer?Max
#
# Welcome Max to the Hall of Doors...
# You stand in a vast, circular hall. In front of you are five mysterious, ornate doors, each shimmering with a different color. A soft voice whispers, 'Choose a door, and an adventure will unfold.'
#
# Choose a number 1, 2, 3, 4, or 5: 2
#  Max, you chose the Emerald Door and are now are transported to a wondrous adventure in Costa Rica!
# Do you A) zipline through the misty cloud forest canopy? or B) watch sea turtles nest on a moonlit beach?a
# As you soar through the trees, you spot a rare, vibrant quetzal bird. Your adventure is a thrilling encounter with wildlife!
#
#  Thank you Max for playing the Hall of Doors!  We hope to see you again!
